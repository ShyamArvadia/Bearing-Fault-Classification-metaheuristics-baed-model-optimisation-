# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !pip install -q efficientnet
# Out:
#      |████████████████████████████████| 50 kB 3.9 MB/s

# %%
'''!pip install split_folders
import splitfolders
[35,2],[40,2],[30,9],[50,2],[30,7],
#ztlist = [[35,9],[35,7],[60,2],[40,7],[40,9],[60,1],[30,2]] 
ztlist =[(39, 3), (41, 6), (39, 5), (17, 2), (17, 3), (29, 4), (46, 6), (14, 4), (43, 5), (31, 4), (10, 7), (12, 3), (42, 2), (56, 8), (49, 2), (59, 3), (49, 4),(51, 4), (49, 10), (47, 8), (15, 7), (13, 4), (34, 2), (29, 3), (40, 4), (12, 8)]



for item in ztlist:

  input_folder = "/content/gdrive/MyDrive/MP(Inner-Outer)/48kpart2/" + "z=" + str(item[0])+", "+"t=" + str(item[1])
 
  output ="/content/gdrive/MyDrive/MP(I-0)split/48kpart2/" + "z=" + str(item[0])+", "+"t=" + str(item[1])
  
  splitfolders.ratio(input_folder, output, seed=42, ratio=(.8, .1, .1))

# %%
'''
# !pip install split_folders
import splitfolders

klist= ['k2','k4','k6','k7','k8','k9','k10']

folderlist =['0 hp_352','1 hp_352','2 hp_352','3 hp_352']

for k in klist:

  for item in folderlist:

    input_folder = "/content/gdrive/MyDrive/SDP Dataset 12k/Motor/" + item
  
    output ="/content/gdrive/MyDrive/SDP Dataset 12k/" + k + "/" + item
    
    splitfolders.ratio(input_folder, output, ratio=(.8, .1, .1))

  print("done: ", k)
# Out:
# ...
# Copying files: 2185 files [01:03, 34.45 files/s]
# Copying files: 2182 files [01:02, 35.07 files/s]
# Copying files: 2182 files [01:00, 35.85 files/s]
# Copying files: 2185 files [01:00, 36.02 files/s]
# Copying files: 2185 files [00:32, 68.03 files/s]
# Copying files: 2182 files [00:31, 68.99 files/s]
# Copying files: 2182 files [00:32, 67.87 files/s]
# Copying files: 2185 files [00:31, 68.43 files/s]
# Copying files: 2185 files [00:31, 68.80 files/s]
# Copying files: 2182 files [00:31, 68.33 files/s]
# Copying files: 2182 files [00:31, 69.78 files/s]
# Copying files: 2185 files [00:33, 64.87 files/s]
# Copying files: 2185 files [00:31, 69.71 files/s]
# Copying files: 2182 files [00:31, 70.14 files/s]
# Copying files: 2182 files [00:31, 69.79 files/s]
# Copying files: 2185 files [00:31, 69.59 files/s]
# Copying files: 2185 files [00:31, 68.94 files/s]
# Copying files: 2182 files [00:31, 69.29 files/s]
# Copying files: 2182 files [00:31, 69.53 files/s]
# ...

# %%
# !pip install split_folders
import splitfolders


input_folder = "/content/gdrive/MyDrive/SDP Dataset 12k/16class"
 
output ="/content/gdrive/MyDrive/SDP Dataset 12k/16class_k2"
  
splitfolders.ratio(input_folder, output, ratio=(.8, .1, .1))
# Out:
# ...
# Copying files: 8734 files [02:50, 51.33 files/s]

# %%
train_dir = '/content/gdrive/MyDrive/SDP Dataset 12k/16class_k2/train'
val_dir   = '/content/gdrive/MyDrive/SDP Dataset 12k/16class_k2/val'
test_dir_1 = '/content/gdrive/MyDrive/SDP Dataset 12k/16class_k2/test'
# test_dir_2 = '/content/gdrive/MyDrive/SDP Dataset 12k/Motor Split/1 hp_352/train'
# test_dir_3 = '/content/gdrive/MyDrive/SDP Dataset 12k/Motor Split/2 hp_352/train'
# test_dir_4 = '/content/gdrive/MyDrive/SDP Dataset 12k/Motor Split/3 hp_352/train'

# %%
import os
train_BF0_fnames = os.listdir(train_dir+'/BF0')
train_NF0_fnames = os.listdir(train_dir+'/NF0' )
train_OF0_fnames = os.listdir(train_dir+'/OF0')
train_IF0_fnames = os.listdir(train_dir+'/IF0')
train_NF1_fnames = os.listdir(train_dir+'/NF1' )
train_BF1_fnames = os.listdir(train_dir+'/BF1')
train_OF1_fnames = os.listdir(train_dir+'/OF1')
train_IF1_fnames = os.listdir(train_dir+'/IF1')
train_NF2_fnames = os.listdir(train_dir+'/NF2' )
train_BF2_fnames = os.listdir(train_dir+'/BF2')
train_OF2_fnames = os.listdir(train_dir+'/OF2')
train_IF2_fnames = os.listdir(train_dir+'/IF2')
train_NF3_fnames = os.listdir(train_dir+'/NF3' )
train_BF3_fnames = os.listdir(train_dir+'/BF3')
train_OF3_fnames = os.listdir(train_dir+'/OF3')
train_IF3_fnames = os.listdir(train_dir+'/IF3')

# %%
print(len(train_NF_fnames))
print(len(train_BF_fnames))
print(len(train_IF_fnames))
print(len(train_OF_fnames))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0a73b2fd8ca2> in <module>()
# ----> 1 print(len(train_NF_fnames))
#       2 print(len(train_BF_fnames))
#       3 print(len(train_IF_fnames))
#       4 print(len(train_OF_fnames))
#
# NameError: name 'train_NF_fnames' is not defined

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 10x10 configuration
nrows = 8
ncols = 8

# Index for iterating over images
pic_index = 0

# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_NF_pix = [os.path.join(train_dir+'/NF', fname) 
                for fname in train_NF_fnames[pic_index-8:pic_index]]
next_BF_pix = [os.path.join(train_dir+'/BF', fname) 
                for fname in train_BF_fnames[pic_index-8:pic_index]]
next_OF_pix = [os.path.join(train_dir+'/OF', fname) 
                for fname in train_OF_fnames[pic_index-8:pic_index]]
next_IF_pix = [os.path.join(train_dir+'/IF', fname) 
                for fname in train_IF_fnames[pic_index-8:pic_index]]                


for i, img_path in enumerate(next_NF_pix+next_BF_pix+next_OF_pix+next_IF_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)
  

plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

target_size= (123,123)
batch_size = 32

# %%
#k fold

accuracy_list= []

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=0,
    width_shift_range=0,
    height_shift_range=0,
    shear_range=0,
    zoom_range=0,
    horizontal_flip=False,
    vertical_flip=False)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=target_size,
    batch_size=batch_size,
    color_mode='rgb',    
    shuffle=False,
    class_mode='categorical')

val_datagen = ImageDataGenerator(rescale=1./255)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=target_size,
    batch_size=batch_size,
    color_mode='rgb',
    shuffle=False,    
    class_mode='categorical')
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of accelerators:  1

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=0,
    width_shift_range=0,
    height_shift_range=0,
    shear_range=0,
    zoom_range=0,
    horizontal_flip=False,
    vertical_flip=False)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=target_size,
    batch_size=batch_size,
    color_mode='rgb',    
    shuffle=False,
    seed=42,
    class_mode='categorical')
# Out:
# Found 6983 images belonging to 16 classes.

# %%
val_datagen = ImageDataGenerator(rescale=1./255)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=target_size,
    batch_size=batch_size,
    color_mode='rgb',
    shuffle=False,    
    class_mode='categorical')
# Out:
# Found 864 images belonging to 16 classes.

# %%
test_datagen_1 = ImageDataGenerator(rescale=1./255 )

test_generator_1 = test_datagen_1.flow_from_directory(
    test_dir_1,
    target_size=target_size,
    batch_size=batch_size,
    color_mode='rgb',
    shuffle=False,     
    class_mode='categorical')
# Out:
# Found 887 images belonging to 16 classes.

# %%
test_datagen_2 = ImageDataGenerator(rescale=1./255 )

test_generator_2 = test_datagen_2.flow_from_directory(
    test_dir_2,
    target_size=target_size,
    batch_size=batch_size,
    color_mode='rgb',
    shuffle=False,     
    class_mode='categorical')
# Out:
# Found 1747 images belonging to 4 classes.

# %%
test_datagen_3 = ImageDataGenerator(rescale=1./255 )

test_generator_3 = test_datagen_3.flow_from_directory(
    test_dir_3,
    target_size=target_size,
    batch_size=batch_size,
    color_mode='rgb',
    shuffle=False,     
    class_mode='categorical')
# Out:
# Found 1745 images belonging to 4 classes.

# %%
test_datagen_4 = ImageDataGenerator(rescale=1./255 )

test_generator_4 = test_datagen_4.flow_from_directory(
    test_dir_4,
    target_size=target_size,
    batch_size=batch_size,
    color_mode='rgb',
    shuffle=False,     
    class_mode='categorical')
# Out:
# Found 1744 images belonging to 4 classes.

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VAL  =val_generator.n//val_generator.batch_size
STEP_SIZE_TEST =test_generator_1.n//test_generator_1.batch_size

# %%
num_classes = 16
input_shape = (123,123,3)

# %%
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dense
from tensorflow.keras.layers import (
    AvgPool2D,
    GlobalAveragePooling2D,
    MaxPool2D,
)
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import ReLU, concatenate, Dropout

# %%
demo_model2 = Sequential([
    layers.Conv2D(32,3,use_bias = True ,activation= 'relu', input_shape = (123,123,3)),
    layers.AveragePooling2D(2),
    layers.Conv2D(64,5,use_bias = True,activation = 'relu'),
    layers.AveragePooling2D(2),
    layers.Conv2D(128,7,use_bias = True,activation = 'relu'),
    layers.AveragePooling2D(2),
    # layers.Conv2D(16,1,use_bias = True,activation = 'relu'),
    # layers.AveragePooling2D(2)
    layers.Flatten(),
    layers.Dense(128,activation = 'relu',use_bias = True),
    layers.Dense(96, activation = 'relu',use_bias = True),
    layers.Dense(num_classes, activation = 'softmax',use_bias = True)
])
model=demo_model2 
model.summary()
model.compile(loss = "categorical_crossentropy", optimizer = 'adam', metrics = ["accuracy"])
es = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience = 15, restore_best_weights=True)
history = model.fit(train_generator,steps_per_epoch=STEP_SIZE_TRAIN, validation_data=val_generator, validation_steps=STEP_SIZE_VAL, epochs=200,callbacks = [es])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_24 (Conv2D)          (None, 121, 121, 32)      896
#
#  average_pooling2d_18 (Avera  (None, 60, 60, 32)       0
#  gePooling2D)
#
#  conv2d_25 (Conv2D)          (None, 56, 56, 64)        51264
#
#  average_pooling2d_19 (Avera  (None, 28, 28, 64)       0
#  gePooling2D)
#
#  conv2d_26 (Conv2D)          (None, 22, 22, 128)       401536
#
#  average_pooling2d_20 (Avera  (None, 11, 11, 128)      0
#  gePooling2D)
#
#  flatten_8 (Flatten)         (None, 15488)             0
#
#  dense_24 (Dense)            (None, 128)               1982592
#
#  dense_25 (Dense)            (None, 96)                12384
#
#  dense_26 (Dense)            (None, 16)                1552
#
# ...
# Total params: 2,450,224
# Trainable params: 2,450,224
# Non-trainable params: 0
# _________________________________________________________________
# ...

# %%
# Copy model from research paper
import tensorflow
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dense
from tensorflow.keras.layers import (
    AvgPool2D,
    GlobalAveragePooling2D,
    MaxPool2D,
)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import ReLU, concatenate, Dropout

papermodel = models.Sequential()
papermodel.add(layers.Conv2D(filters = 32, kernel_size = (3, 3), input_shape = (123,123,3)))
papermodel.add(layers.BatchNormalization())
papermodel.add(layers.Conv2D(filters = 32, kernel_size = (3, 3)))
papermodel.add(layers.MaxPooling2D(2,2))
papermodel.add(layers.Conv2D(filters = 32, kernel_size = (3, 3)))
papermodel.add(layers.Dropout(0.35))
papermodel.add(layers.ReLU())
papermodel.add(layers.Flatten())
papermodel.add(layers.Dense(units = 1024))
papermodel.add(layers.Dense(units = 256))
papermodel.add(layers.Dropout(0.25))
papermodel.add(layers.Dense(num_classes, activation= "softmax"))

papermodel.summary()

papermodel.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_27 (Conv2D)          (None, 121, 121, 32)      896
#
#  batch_normalization_2 (Batc  (None, 121, 121, 32)     128
#  hNormalization)
#
#  conv2d_28 (Conv2D)          (None, 119, 119, 32)      9248
#
#  max_pooling2d_2 (MaxPooling  (None, 59, 59, 32)       0
#  2D)
#
#  conv2d_29 (Conv2D)          (None, 57, 57, 32)        9248
#
#  dropout_4 (Dropout)         (None, 57, 57, 32)        0
#
#  re_lu_2 (ReLU)              (None, 57, 57, 32)        0
#
#  flatten_9 (Flatten)         (None, 103968)            0
#
#  dense_27 (Dense)            (None, 1024)              106464256
#
#  dense_28 (Dense)            (None, 256)               262400
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_29 (Dense)            (None, 16)                4112
#
# ...
# Total params: 106,750,288
# ...

# %%
import keras

early_stopping_monitor = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=15,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)

history = papermodel.fit(train_generator,steps_per_epoch=STEP_SIZE_TRAIN,epochs=200, validation_data=val_generator, validation_steps=STEP_SIZE_VAL, callbacks=early_stopping_monitor)
# Out:
# Epoch 1/200
# 218/218 [==============================] - 28s 123ms/step - loss: 29.3182 - accuracy: 0.1326 - val_loss: 2.7840 - val_accuracy: 0.0556
# Epoch 2/200
# 218/218 [==============================] - 26s 118ms/step - loss: 2.3061 - accuracy: 0.2191 - val_loss: 2.6174 - val_accuracy: 0.1470
# Epoch 3/200
# 218/218 [==============================] - 26s 118ms/step - loss: 2.0864 - accuracy: 0.2479 - val_loss: 2.6448 - val_accuracy: 0.1956
# Epoch 4/200
# 218/218 [==============================] - 26s 118ms/step - loss: 2.0807 - accuracy: 0.2838 - val_loss: 9.6764 - val_accuracy: 0.1620
# Epoch 5/200
# 218/218 [==============================] - 26s 118ms/step - loss: 1.9477 - accuracy: 0.3136 - val_loss: 8.4025 - val_accuracy: 0.1319
# Epoch 6/200
# 218/218 [==============================] - 26s 119ms/step - loss: 33.0532 - accuracy: 0.1026 - val_loss: 2.7880 - val_accuracy: 0.0694
# Epoch 7/200
# ...

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dense
from tensorflow.keras.layers import (
    AvgPool2D,
    GlobalAveragePooling2D,
    MaxPool2D,
)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import ReLU, concatenate


def conv_layer(x, filters, kernel=1, strides=1):

    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Conv2D(filters, kernel, strides=strides, padding="same")(x)
    return x


def dense_block(x, repetition, filters):

    for _ in range(repetition):
        y = conv_layer(x, 4 * filters)
        y = conv_layer(y, filters, 3)
        x = concatenate([y, x])
    return x


def transition_layer(x):

    x = conv_layer(x, x.shape[-1] // 2)
    x = AvgPool2D(2, strides=2, padding="same")(x)
    return x


def densenet(input_shape, n_classes, filters=32):

    input = Input(input_shape)
    x = Conv2D(64, 7, strides=2, padding="same")(input)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool2D(3, strides=2, padding="same")(x)

    for repetition in [6, 12, 24, 16]:

        d = dense_block(x, repetition, filters)
        x = transition_layer(d)
    x = GlobalAveragePooling2D()(d)
    output = Dense(n_classes, activation="softmax")(x)

    model = Model(input, output)
    return model


input_shape = 123, 123, 3
n_classes = 4

densemodel = densenet(input_shape, n_classes, filters=32)
densemodel.summary()
densemodel.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 123, 123, 3  0           []
#                                 )]
#
#  conv2d_369 (Conv2D)            (None, 62, 62, 64)   9472        ['input_4[0][0]']
#
#  batch_normalization_365 (Batch  (None, 62, 62, 64)  256         ['conv2d_369[0][0]']
#  Normalization)
#
#  re_lu_365 (ReLU)               (None, 62, 62, 64)   0           ['batch_normalization_365[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 31, 31, 64)  0           ['re_lu_365[0][0]']
#
#  batch_normalization_366 (Batch  (None, 31, 31, 64)  256         ['max_pooling2d_5[0][0]']
#  Normalization)
#
#  re_lu_366 (ReLU)               (None, 31, 31, 64)   0           ['batch_normalization_366[0][0]']
#
#  conv2d_370 (Conv2D)            (None, 31, 31, 128)  8320        ['re_lu_366[0][0]']
# ...

# %%
import keras

early_stopping_monitor = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=5,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)

history = densemodel.fit(train_generator,steps_per_epoch=STEP_SIZE_TRAIN,epochs=num_epochs, validation_data=val_generator, validation_steps=STEP_SIZE_VAL, callbacks=early_stopping_monitor)
# Out:
# Epoch 1/200
# 54/54 [==============================] - 26s 224ms/step - loss: 5.4952 - accuracy: 0.2845 - val_loss: 1.5120 - val_accuracy: 0.2500
# Epoch 2/200
# 54/54 [==============================] - 8s 141ms/step - loss: 2.3928 - accuracy: 0.1994 - val_loss: 1.4857 - val_accuracy: 0.1875
# Epoch 3/200
# 54/54 [==============================] - 8s 144ms/step - loss: 1.9550 - accuracy: 0.2659 - val_loss: 1.3983 - val_accuracy: 0.2708
# Epoch 4/200
# 54/54 [==============================] - 8s 145ms/step - loss: 1.6673 - accuracy: 0.3172 - val_loss: 1.3619 - val_accuracy: 0.3073
# Epoch 5/200
# 54/54 [==============================] - 8s 144ms/step - loss: 1.3114 - accuracy: 0.3819 - val_loss: 1.0970 - val_accuracy: 0.4115
# Epoch 6/200
# 54/54 [==============================] - 8s 142ms/step - loss: 1.0095 - accuracy: 0.5248 - val_loss: 458.4027 - val_accuracy: 0.1875
# Epoch 7/200
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Add,AveragePooling2D,Dense, AvgPool2D,BatchNormalization, ReLU, DepthwiseConv2D, Reshape, Permute,Conv2D, MaxPool2D, GlobalAveragePooling2D, concatenate, Dropout


def channel_shuffle(x, groups):  
    _, width, height, channels = x.get_shape().as_list()
    group_ch = channels // groups

    x = Reshape([width, height, group_ch, groups])(x)
    x = Permute([1, 2, 4, 3])(x)
    x = Reshape([width, height, channels])(x)
    return x

def shuffle_unit(x, groups, channels,strides):

    y = x
    x = Conv2D(channels//4, kernel_size = 1, strides = (1,1),padding = 'same', groups=groups)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    x = channel_shuffle(x, groups)
    
    x = DepthwiseConv2D(kernel_size = (3,3), strides = strides, padding = 'same')(x)
    x = BatchNormalization()(x)
    

    if strides == (2,2):
        channels = channels - y.shape[-1]
    x = Conv2D(channels, kernel_size = 1, strides = (1,1),padding = 'same', groups=groups)(x)
    x = BatchNormalization()(x)
    

    if strides ==(1,1):
        x =Add()([x,y])
    if strides == (2,2):
        y = AvgPool2D((3,3), strides = (2,2), padding = 'same')(y)
        x = concatenate([x,y])
    
    x = ReLU()(x)
    


    return x


def Shuffle_Net(nclasses, start_channels ,input_shape = (123,123,3)):

    groups = 2
    input = Input (input_shape)

    x =  Conv2D (24,kernel_size=3,strides = (2,2), padding = 'same', use_bias = True)(input)
    x =  BatchNormalization()(x)
    x =  ReLU()(x)
    
    x = MaxPool2D (pool_size=(3,3), strides = 2, padding='same')(x)

    repetitions = [3,7,3]

    for i,repetition in enumerate(repetitions):
        channels = start_channels * (2**i)

        x  = shuffle_unit(x, groups, channels,strides = (2,2))

        for i in range(repetition):
            x = shuffle_unit(x, groups, channels,strides=(1,1))

    x = GlobalAveragePooling2D()(x)

    output = Dense(n_classes,activation='softmax')(x)

    model = Model(input, output)
    return model


n_classes = 4
input_shape = (123,123,3)
start_channels = 200

shufflemodel = Shuffle_Net(n_classes, start_channels,input_shape)
shufflemodel.summary()

shufflemodel.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_6 (InputLayer)           [(None, 123, 123, 3  0           []
#                                 )]
#
#  conv2d_523 (Conv2D)            (None, 62, 62, 24)   672         ['input_6[0][0]']
#
#  batch_normalization_535 (Batch  (None, 62, 62, 24)  96          ['conv2d_523[0][0]']
#  Normalization)
#
#  re_lu_519 (ReLU)               (None, 62, 62, 24)   0           ['batch_normalization_535[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 31, 31, 24)  0           ['re_lu_519[0][0]']
#
#  conv2d_524 (Conv2D)            (None, 31, 31, 50)   650         ['max_pooling2d_7[0][0]']
#
#  batch_normalization_536 (Batch  (None, 31, 31, 50)  200         ['conv2d_524[0][0]']
#  Normalization)
#
#  re_lu_520 (ReLU)               (None, 31, 31, 50)   0           ['batch_normalization_536[0][0]']
# ...

# %%
import keras

early_stopping_monitor = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=5,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)

history = shufflemodel.fit(train_generator,steps_per_epoch=STEP_SIZE_TRAIN,epochs=num_epochs, validation_data=val_generator, validation_steps=STEP_SIZE_VAL, callbacks=early_stopping_monitor)
# Out:
# Epoch 1/200
# 54/54 [==============================] - 10s 95ms/step - loss: 2.3118 - accuracy: 0.3341 - val_loss: 1.3773 - val_accuracy: 0.3125
# Epoch 2/200
# 54/54 [==============================] - 4s 73ms/step - loss: 1.3081 - accuracy: 0.5050 - val_loss: 1.3884 - val_accuracy: 0.2500
# Epoch 3/200
# 54/54 [==============================] - 4s 73ms/step - loss: 1.5000 - accuracy: 0.4851 - val_loss: 1.3886 - val_accuracy: 0.2500
# Epoch 4/200
# 54/54 [==============================] - 4s 73ms/step - loss: 1.3983 - accuracy: 0.5487 - val_loss: 1.4059 - val_accuracy: 0.1875
# Epoch 5/200
# 54/54 [==============================] - 4s 72ms/step - loss: 1.0097 - accuracy: 0.5988 - val_loss: 1.4029 - val_accuracy: 0.3125
# Epoch 6/200
# 54/54 [==============================] - 4s 74ms/step - loss: 1.1356 - accuracy: 0.5726 - val_loss: 1.4422 - val_accuracy: 0.2500

# %%
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D, ReLU, BatchNormalization, add,Softmax, AveragePooling2D, Dense, Input, GlobalAveragePooling2D
from tensorflow.keras.models import Model

def expansion_block(x,t,filters,block_id):
    prefix = 'block_{}_'.format(block_id)
    total_filters = t*filters
    x = Conv2D(total_filters,1,padding='same',use_bias=False, name = prefix +'expand')(x)
    x = BatchNormalization(name=prefix +'expand_bn')(x)
    x = ReLU(6,name = prefix +'expand_relu')(x)
    return x

def depthwise_block(x,stride,block_id):
    prefix = 'block_{}_'.format(block_id)
    x = DepthwiseConv2D(3,strides=(stride,stride),padding ='same', use_bias = False, name = prefix + 'depthwise_conv')(x)
    x = BatchNormalization(name=prefix +'dw_bn')(x)
    x = ReLU(6,name=prefix +'dw_relu')(x)
    return x

def projection_block(x,out_channels,block_id):
    prefix = 'block_{}_'.format(block_id)
    x = Conv2D(filters = out_channels,kernel_size = 1,padding='same',use_bias=False,name= prefix + 'compress')(x)
    x = BatchNormalization(name=prefix +'compress_bn')(x)
    return x


def Bottleneck(x,t,filters, out_channels,stride,block_id):
    y = expansion_block(x,t,filters,block_id)
    y = depthwise_block(y,stride,block_id)
    y = projection_block(y, out_channels,block_id)
    if y.shape[-1]==x.shape[-1]:
        y = add([x,y])
    return y

def MobileNetV2(input_image = (224,224,3), n_classes=1000):
    input = Input(input_image)

    x = Conv2D(32,kernel_size=3,strides=(2,2),padding = 'same', use_bias=False)(input)
    x = BatchNormalization(name='conv1_bn')(x)
    x = ReLU(6, name = 'conv1_relu')(x)

    # 17 Bottlenecks

    x = depthwise_block(x,stride=1,block_id=1)
    x = projection_block(x, out_channels=16,block_id=1)

    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 2,block_id = 2)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 1,block_id = 3)

    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 2,block_id = 4)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 5)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 6)

    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 2,block_id = 7)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 1,block_id = 8)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 1,block_id = 9)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 1,block_id = 10)

    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 96, stride = 1,block_id = 11)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 96, stride = 1,block_id = 12)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 96, stride = 1,block_id = 13)

    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 2,block_id = 14)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 1,block_id = 15)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 1,block_id = 16)

    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 320, stride = 1,block_id = 17)

    #1*1 conv
    x = Conv2D(filters = 1280,kernel_size = 1,padding='same',use_bias=False, name = 'last_conv')(x)
    x = BatchNormalization(name='last_bn')(x)
    x = ReLU(6,name='last_relu')(x)

    #AvgPool 7*7
    x = GlobalAveragePooling2D(name='global_average_pool')(x)

    output = Dense(n_classes,activation='softmax')(x)

    model = Model(input, output)

    return model

n_classes = 4
input_shape = (123,123,3)

mobilemodel = MobileNetV2(input_shape,n_classes)
mobilemodel.summary()

mobilemodel.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_9 (InputLayer)           [(None, 123, 123, 3  0           []
#                                 )]
#
#  conv2d_558 (Conv2D)            (None, 62, 62, 32)   864         ['input_9[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 62, 62, 32)   128         ['conv2d_558[0][0]']
#
#  conv1_relu (ReLU)              (None, 62, 62, 32)   0           ['conv1_bn[0][0]']
#
#  block_1_depthwise_conv (Depthw  (None, 62, 62, 32)  288         ['conv1_relu[0][0]']
#  iseConv2D)
#
#  block_1_dw_bn (BatchNormalizat  (None, 62, 62, 32)  128         ['block_1_depthwise_conv[0][0]']
#  ion)
#
#  block_1_dw_relu (ReLU)         (None, 62, 62, 32)   0           ['block_1_dw_bn[0][0]']
#
#  block_1_compress (Conv2D)      (None, 62, 62, 16)   512         ['block_1_dw_relu[0][0]']
#
# ...

# %%
import keras

early_stopping_monitor = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=5,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)

history = mobilemodel.fit(train_generator,steps_per_epoch=STEP_SIZE_TRAIN,epochs=num_epochs, validation_data=val_generator, validation_steps=STEP_SIZE_VAL, callbacks=early_stopping_monitor)
# Out:
# Epoch 1/200
# 54/54 [==============================] - 10s 103ms/step - loss: 1.7256 - accuracy: 0.3586 - val_loss: 1.4073 - val_accuracy: 0.3125
# Epoch 2/200
# 54/54 [==============================] - 4s 76ms/step - loss: 1.2595 - accuracy: 0.3592 - val_loss: 1.4029 - val_accuracy: 0.3125
# Epoch 3/200
# 54/54 [==============================] - 4s 77ms/step - loss: 0.9670 - accuracy: 0.4822 - val_loss: 1.4618 - val_accuracy: 0.1875
# Epoch 4/200
# 54/54 [==============================] - 4s 75ms/step - loss: 1.0862 - accuracy: 0.5557 - val_loss: 1.9382 - val_accuracy: 0.1875
# Epoch 5/200
# 54/54 [==============================] - 4s 76ms/step - loss: 0.9386 - accuracy: 0.5854 - val_loss: 2.0053 - val_accuracy: 0.1875
# Epoch 6/200
# 54/54 [==============================] - 4s 76ms/step - loss: 1.0269 - accuracy: 0.4653 - val_loss: 1.9405 - val_accuracy: 0.1875

# %%
import efficientnet.tfkeras as efn
from tensorflow.keras import models, layers, optimizers, regularizers, callbacks, metrics


base_model = efn.EfficientNetB7(input_shape=input_shape, include_top=False ,weights='imagenet')
base_model.trainable = False # (transfer learning)

# for layer in base_model.layers[20:]:
#   layer.trainable = True

# for layer in base_model.layers[-50:]:
#   layer.trainable = True

x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation = "relu")(x)

out = layers.Dense(num_classes, activation="softmax")(x)

effmodel = models.Model(inputs=base_model.input, outputs=out)
effmodel.summary()
# Out:
# ...
# 258449408/258434480 [==============================] - 10s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 123, 123, 3  0           []
#                                 )]
#
#  stem_conv (Conv2D)             (None, 62, 62, 64)   1728        ['input_1[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 62, 62, 64)   256         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 62, 62, 64)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 62, 62, 64)  576         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 62, 62, 64)  256         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 62, 62, 64)  0           ['block1a_bn[0][0]']
#  )
#
# ...

# %%
# compile model

'''import tensorflow as tf

effmodel.compile(loss='categorical_crossentropy', optimizer= tf.keras.optimizers.Adam(0.0001), metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-69483a3d8677> in <module>()
#       3 import tensorflow as tf
#       4
# ----> 5 effmodel.compile(loss='categorical_crossentropy', optimizer= tf.keras.optimizers.Adam, metrics=['accuracy'])
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/optimizers.py in get(identifier)
#     143   else:
#     144     raise ValueError(
# --> 145         'Could not interpret optimizer identifier: {}'.format(identifier))
#
# ...

# %%
effmodel.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
#model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=[metrics.AUC(from_logits=True)])

# %%
## set Checkpoint : save best only, verbose on
#checkpoint = callbacks.ModelCheckpoint("railtrack_enetB7.hdf5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto', save_freq=1)

# %%
import keras



early_stopping_monitor = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=10,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)

history = effmodel.fit(train_generator,steps_per_epoch=STEP_SIZE_TRAIN,epochs=100, validation_data=val_generator, validation_steps=STEP_SIZE_VAL, callbacks=early_stopping_monitor)
# Out:
# Epoch 1/100
# 109/109 [==============================] - 548s 5s/step - loss: 1.5006 - accuracy: 0.3559 - val_loss: 1.3449 - val_accuracy: 0.4327
# Epoch 2/100
# 109/109 [==============================] - 8s 71ms/step - loss: 1.3551 - accuracy: 0.3085 - val_loss: 1.3105 - val_accuracy: 0.2885
# Epoch 3/100
# 109/109 [==============================] - 8s 74ms/step - loss: 1.3232 - accuracy: 0.3478 - val_loss: 1.2591 - val_accuracy: 0.5144
# Epoch 4/100
# 109/109 [==============================] - 8s 71ms/step - loss: 1.3107 - accuracy: 0.3928 - val_loss: 1.3660 - val_accuracy: 0.2596
# Epoch 5/100
# 109/109 [==============================] - 8s 74ms/step - loss: 1.2357 - accuracy: 0.4027 - val_loss: 1.0578 - val_accuracy: 0.5577
# Epoch 6/100
# 109/109 [==============================] - 8s 71ms/step - loss: 1.2163 - accuracy: 0.4379 - val_loss: 1.2016 - val_accuracy: 0.3942
# Epoch 7/100
# ...

# %%
base_model.trainable = True

# %%
len(base_model.layers)

fine_tune_at = 600

for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False

# %%
import tensorflow as tf

effmodel.compile(loss='categorical_crossentropy', optimizer= tf.keras.optimizers.Adam(0.0001), metrics=['accuracy'])

# %%
effmodel.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 123, 123, 3  0           []
#                                 )]
#
#  stem_conv (Conv2D)             (None, 62, 62, 64)   1728        ['input_1[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 62, 62, 64)   256         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 62, 62, 64)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 62, 62, 64)  576         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 62, 62, 64)  256         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 62, 62, 64)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 64)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
# ...

# %%
len(effmodel.trainable_variables)
# Out:
# 183

# %%
fine_tune_epochs = 100

total_epochs =  41 + fine_tune_epochs

early_stopping_monitor = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=5,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)

history = effmodel.fit(train_generator,steps_per_epoch=STEP_SIZE_TRAIN,epochs=total_epochs,initial_epoch=history.epoch[-1], validation_data=val_generator, validation_steps=STEP_SIZE_VAL, callbacks=early_stopping_monitor)
# Out:
# Epoch 41/141
# 109/109 [==============================] - 36s 151ms/step - loss: 1.7362 - accuracy: 0.2588 - val_loss: 1.0596 - val_accuracy: 0.5240
# Epoch 42/141
# 109/109 [==============================] - 12s 113ms/step - loss: 1.5064 - accuracy: 0.2559 - val_loss: 1.1474 - val_accuracy: 0.5529
# Epoch 43/141
# 109/109 [==============================] - 12s 110ms/step - loss: 1.4552 - accuracy: 0.2611 - val_loss: 1.2437 - val_accuracy: 0.4279
# Epoch 44/141
# 109/109 [==============================] - 12s 110ms/step - loss: 1.4162 - accuracy: 0.2629 - val_loss: 1.3157 - val_accuracy: 0.3750
# Epoch 45/141
# 109/109 [==============================] - 12s 110ms/step - loss: 1.3861 - accuracy: 0.2900 - val_loss: 1.3127 - val_accuracy: 0.3413
# Epoch 46/141
# 109/109 [==============================] - 12s 110ms/step - loss: 1.3576 - accuracy: 0.3056 - val_loss: 1.2223 - val_accuracy: 0.4183
# Epoch 47/141
# ...

# %%
'''import keras

import tensorflow as devam

base_model.trainable = True

model.compile(loss='categorical_crossentropy', optimizer= devam.keras.optimizers.Adam(learning_rate=1e-5), metrics=['accuracy'])



early_stopping_monitor = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=5,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)

history = model.fit(train_generator,steps_per_epoch=STEP_SIZE_TRAIN,epochs=num_epochs, validation_data=val_generator, validation_steps=STEP_SIZE_VAL, callbacks=early_stopping_monitor)

# %%
'''import keras

history = model.fit(train_generator,steps_per_epoch=STEP_SIZE_TRAIN,epochs=num_epochs, validation_data=val_generator, validation_steps=STEP_SIZE_VAL, callbacks=[
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min")])

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-81-ab0e8ebb41cb> in <module>()
#      20 from keras.layers import BatchNormalization
#      21 from keras.regularizers import l2
# ---> 22 from keras.utils.layer_utils import convert_all_kernels_in_model, convert_dense_weights_data_format
#      23 from keras.utils.data_utils import get_file
#      24 from keras.engine.topology import get_source_inputs
#
# ImportError: cannot import name 'convert_all_kernels_in_model' from 'keras.utils.layer_utils' (/usr/local/lib/python3.7/dist-packages/keras/utils/layer_utils.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-b02de02f6ed5> in <module>()
#       1 # compile model
#       2 dense = create_dense_net(4, input_shape, depth=40, nb_dense_block=3, growth_rate=12, nb_filter=16, dropout_rate=None,
# ----> 3                      weight_decay=1E-4, verbose=True)
#       4
#       5 import tensorflow as tf
#
# <ipython-input-77-7b5ed6d79603> in create_dense_net(nb_classes, img_dim, depth, nb_dense_block, growth_rate, nb_filter, dropout_rate, weight_decay, verbose)
#     107     # Initial convolution
#     108     x = Convolution2D(nb_filter, 3, 3, init="he_uniform", border_mode="same", name="initial_conv2D", bias=False,
# --> 109                       W_regularizer=l2(weight_decay))(model_input)
#     110
#     111     x = BatchNormalization(mode=0, gamma_regularizer=l2(weight_decay),
#
# ...

# %%
papermodel.evaluate(test_generator)
# Out:
# 7/7 [==============================] - 113s 19s/step - loss: 0.2860 - accuracy: 0.9099
# [0.2860407829284668, 0.9099099040031433]

# %%
# models.save_model(papermodel, '/content/gdrive/MyDrive/SDP Dataset/models/papermodel_48khz_307.h5')
papermodel.load_weights("/content/gdrive/MyDrive/SDP Dataset/models/papermodel_48khz_307.h5")

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd
import seaborn as sn
labels = ['BF', 'IF','NF','OF']
predY=papermodel.predict(test_generator) 
y_pred = np.argmax(predY,axis=1)
y_actual = test_generator.classes
cm = confusion_matrix(y_actual, y_pred)
df_cm = pd.DataFrame(cm, labels,labels)
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
print(cm)
# Out:
# [[45  3  0  1]
#  [ 1 48  0  0]
#  [ 0  0 62  0]
#  [10  5  0 47]]

# %%
labeldic = {}
for key,value in  test_generator.class_indices.items():
    labeldic[value] = key
print(labeldic)
# Out:
# {0: 'BF', 1: 'IF', 2: 'NF', 3: 'OF'}

# %%
A=(y_pred!=y_actual)
# print(A)
miscl= np.where(A)
miscl = miscl[0]
# print(miscl)
# Out:
# [False False False False  True False False  True  True False False  True
#   True False False False False False False False False False False False
#  False False False False False False False False  True False False False
#   True False  True False False False False False False False False False
#  False  True False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
# ...

# %%
batchid = []
# print(miscl[3])
for x in miscl : 
  i = int(x/16)
  n = x%16
  batchid.append((i,n,x)) 
print(batchid)
# Out:
# [(0, 4, 4), (0, 7, 7), (0, 8, 8), (0, 11, 11), (0, 12, 12), (2, 0, 32), (2, 4, 36), (2, 6, 38), (3, 1, 49), (15, 4, 244), (16, 12, 268), (18, 5, 293)]

# %%
len(test_generator[18][0])
# Out:
# 7

# %% [markdown]
# ```
# `# This is formatted as code`
# ```
#
# After much hardwork by Shyam :
# # Extracting misclassified images

# %%
# for batch in test_generator:
#   images = batch[0]
#   labels = batch[1]
#   for i in range(len(labels)):
#     plt.imshow(images[i])
#     print(labels[i])
labeldic = {}
for key,value in  test_generator.class_indices.items():
    labeldic[value] = key
print(labeldic)
#Boolean of misclassified , True = misclassified
A=(y_pred!=y_actual)
# print(A)
miscl= np.where(A)
miscl = miscl[0]

#Getting Batch id and Imno in Batch
batchid = []
# print(miscl[3])
for x in miscl : 
  i = int(x/16)
  n = x%16
  batchid.append((i,n,x)) 
# print(batchid)

def plotmis(image,acl,prl,idx):
  plt.imshow(image)
  plt.gca().set_xticks([])
  plt.gca().set_yticks([])
  plt.xlabel('predicted : ' + prl + " " + str(idx))
  plt.ylabel('actual: ' + acl )
fig = plt.gcf()
fig.set_size_inches(6 * 4, 2 * 4)
for i,mis in enumerate(batchid) :
    batch = mis[0]
    imno = mis[1]
    idx = mis[2]
    image = test_generator[batch][0][imno]
    aclabel = labeldic[y_actual[idx]]
    prelabel = labeldic[y_pred[idx]]
    ax = plt.subplot(2,6,i+1)
    plotmis(image,aclabel,prelabel,idx)
# for batch in test_generator:

# %%
predY=papermodel.predict(test_generator) 
y_pred = np.argmax(predY,axis=1)
y_actual = test_generator.classes
print(classification_report(y_actual, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#           BF       0.80      0.92      0.86        49
#           IF       0.86      0.98      0.91        49
#           NF       1.00      1.00      1.00        62
#           OF       0.98      0.76      0.85        62
#
#     accuracy                           0.91       222
#    macro avg       0.91      0.91      0.91       222
# weighted avg       0.92      0.91      0.91       222

# %%
keys=history.history.keys()
print(keys)

def show_train_history(hisData,train,val): 
    plt.plot(hisData.history[train])
    plt.plot(hisData.history[val])
    plt.title('Training History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

show_train_history(history, 'loss', 'val_loss')
show_train_history(history, 'accuracy', 'val_accuracy')
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
